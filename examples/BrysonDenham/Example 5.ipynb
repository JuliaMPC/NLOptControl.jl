# %%
using NLOptControl
using JuMP
using Ipopt
using Parameters
using Plots
gr()

steps = 20; tests = 5;
global t_solve = Array(Float64, steps, tests) 
global abs_error = Array(Float64, steps, tests) 
global status = Array(Symbol, steps, tests) 
global N = [i+1 for i in 1:steps]
global labels = Array(Symbol,tests)
##################################
# Define NLOptControl problem
##################################
function BrysonDenham{T<:Any}(n::NLOpt,x::Array{T,2},u::Array{T,2}) # dynamic constraint equations
  if n.integrationMethod==:tm
    L = size(x)[1];
  else
    L = size(x)[1]-1;
  end
  dx = Array(Any,L,n.numStates)
  dx[:,1] =  @NLexpression(mdl, [j=1:L], x[j,2] );
  dx[:,2] =  @NLexpression(mdl, [j=1:L], u[j,1] );
  return dx
end
L=1/9;
for q in 1:tests
    for j in 1:steps
        for m in 1:2
            if m==1
                global n = NLOpt();
                n = define(n,stateEquations=BrysonDenham,numStates=2,numControls=1,X0=[0.,1],XF=[0.,-1.],XL=[0.,-Inf],XU=[L,Inf],CL=[-Inf],CU=[Inf])
                if q==1
                    n = configure(n::NLOpt,Ni=1,Nck=[N[j]];(:integrationMethod => :ps),(:integrationScheme => :lgrExplicit),(:finalTimeDV => false),(:tf => 1.0))
                elseif q==2
                    n = configure(n::NLOpt,N=N[j];(:integrationMethod => :tm),(:integrationScheme => :bkwEuler),(:finalTimeDV => false),(:tf => 1.0))
                elseif q==3
                    n = configure(n::NLOpt,N=N[j];(:integrationMethod => :tm),(:integrationScheme => :trapezoidal),(:finalTimeDV => false),(:tf => 1.0))
                elseif q==4 
                    n = configure(n::NLOpt,Ni=2,Nck=[N[j],N[j]];(:integrationMethod => :ps),(:integrationScheme => :lgrExplicit),(:finalTimeDV => false),(:tf => 1.0))
                else
                    n = configure(n::NLOpt,Ni=4,Nck=[N[j],N[j],N[j],N[j]];(:integrationMethod => :ps),(:integrationScheme => :lgrExplicit),(:finalTimeDV => false),(:tf => 1.0))
                end
                ##################################
                # Define JuMP problem
                ##################################
                global mdl = Model(solver = IpoptSolver(print_level=1));
                n,x,u,c=OCPdef(mdl,n)
                global obj = integrate(mdl,n,u[:,1];C=0.5,(:variable=>:control),(:integrand=>:squared))
                @NLobjective(mdl, Min, obj)
                solve(mdl)
            else
                t1 = time();
                status[j,q] = solve(mdl);
                t2 = time();
                t_solve[j,q] = t2 - t1;
                abs_error[j,q]=abs(getvalue(obj) - 4/(9*L))/(4/(9*L))*100;
            end
        end
    end
    if n.integrationMethod==:tm
        labels[q] = string(n.integrationScheme); 
    else
        labels[q] = string(n.integrationScheme, " with Ni = ",n.Ni); 
    end
end
# Out:
# WARNING: Method definition BrysonDenham(NLOptControl.NLOpt, Array{#T<:Any, 2}, Array{#T<:Any, 2}) in module Main at In[1]:18 overwritten at In[21]:18.
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded

# %%
p1=plot(0);
for q in 1:tests
    scatter!(t_solve[:,q],abs_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,label= string(labels[q]))
end
ylabel!("% error")
xlabel!("solve time (s)")
#ylims!(0, .1)
#xlims!(0, .1)

p2=plot(0);
for q in 1:tests
    scatter!(t_solve[:,q],N,marker = (:star8, 10-q, 0.9),leg=:bottomright,label = string(labels[q]))
end
ylabel!("N")
xlabel!("solve time (s)")
#xlims!(0, .1)

plot(p1,p2,layout=(2,1),background_color_subplot=RGB(0.2,0.2,0.2), background_color_legend=RGB(1,1,1))
plot!(foreground_color_grid=RGB(1,1,1))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 45.8815,169.674 596.063,169.674 596.063,3.93701 45.8815,3.93701
#   " fill="#313131" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="3" width="551" height="166"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   249.591,167.188 249.591,6.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   472.164,167.188 472.164,6.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,164.984 587.81,164.984
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,120.311 587.81,120.311
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,75.6374 587.81,75.6374
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342
s_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,label = string(labels[q]))
end
xlabel!("N")
ylabel!("% error")

p2=plot(0)
for q in 1:tests
    scatter!(N,abs_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,label = string(labels[q]))
end
xlabel!("N")
ylabel!("% error")
ylims!(0, 30)

p3=plot(0)
for q in 1:tests
    scatter!(N,abs_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,label = string(labels[q]))
end
xlabel!("N")
ylabel!("% error")
ylims!(0, .6)

plot(p1,p2,p3,layout=(3,1),background_color_subplot=RGB(0.2,0.2,0.2), background_color_legend=RGB(1,1,1))
plot!(foreground_color_grid=RGB(1,1,1))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 45.8815,103.007 596.063,103.007 596.063,3.93701 45.8815,3.93701
#   " fill="#313131" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="3" width="551" height="100"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   143.406,101.521 143.406,5.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   279.995,101.521 279.995,5.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   416.585,101.521 416.585,5.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   553.174,101.521 553.174,5.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,100.204 587.81,100.204
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,73.5001 587.81,73.5001
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,46.7964 587.81,46.7964
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,20.0927 587.81,20.0927
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,103.007 596.063,103.007
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   143.406,103.007 143.406,101.521
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   279.995,103.007 279.995,101.521
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   416.585,103.007 416.585,101.521
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   553.174,103.007 553.174,101.521
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,103.007 45.8815,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,100.204 54.1342,100.204
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,73.5001 54.1342,73.5001
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,46.7964 54.1342,46.7964
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,20.0927 54.1342,20.0927
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 143.406, 115.007)" x="143.406" y="115.007">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 279.995, 115.007)" x="279.995" y="115.007">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 416.585, 115.007)" x="416.585" y="115.007">15</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 553.174, 115.007)" x="553.174" y="115.007">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 104.704)" x="44.6815" y="104.704">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 78.0001)" x="44.6815" y="78.0001">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 51.2964)" x="44.6815" y="51.2964">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 24.5927)" x="44.6815" y="24.5927">300</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 320.972, 130.933)" x="320.972" y="130.933">N</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 53.4722)" x="14.4" y="53.4722">% error</text>
# </g>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.9" points="
#   61.4526,94.8519 60.2286,89.8119 55.7966,92.5079 58.4926,88.0759 53.4526,86.8519 58.4926,85.6279 55.7966,81.1959 60.2286,83.8919 61.4526,78.8519 62.6766,83.8919
#   67.1086,81.1959 64.4126,85.6279 69.4526,86.8519 64.4126,88.0759 67.1086,92.5079 62.6766,89.8119 61.4526,94.8519
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#0099ff; fill-opacity:0.9" points="
#   61.4526,94.0519 60.351,89.5159 56.3622,91.9423 58.7886,87.9535 54.2526,86.8519 58.7886,85.7503 56.3622,81.7615 60.351,84.1879 61.4526,79.6519 62.5542,84.1879
#   66.543,81.7615 64.1166,85.7503 68.6526,86.8519 64.1166,87.9535 66.543,91.9423 62.5542,89.5159 61.4526,94.0519
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.9" points="
#   88.7705,86.4717 87.5465,81.4317 83.1145,84.1277 85.8105,79.6957 80.7705,78.4717 85.8105,77.2477 83.1145,72.8157 87.5465,75.5117 88.7705,70.4717 89.9945,75.5117
#   94.4265,72.8157 91.7305,77.2477 96.7705,78.4717 91.7305,79.6957 94.4265,84.1277 89.9945,81.4317 88.7705,86.4717
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#0099ff; fill-opacity:0.9" points="
#   88.7705,85.6717 87.6689,81.1357 83.6801,83.5621 86.1065,79.5733 81.5705,78.4717 86.1065,77.3701 83.6801,73.3813 87.6689,75.8077 88.7705,71.2717 89.8721,75.8077
#   93.8609,73.3813 91.4345,77.3701 95.9705,78.4717 91.4345,79.5733 93.8609,83.5621 89.8721,81.1357 88.7705,85.6717
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.9" points="
#   116.088,108.189 114.864,103.149 110.432,105.845 113.128,101.413 108.088,100.189 113.128,98.9648 110.432,94.5328 114.864,97.2288 116.088,92.1888 117.312,97.2288
#   121.744,94.5328 119.048,98.9648 124.088,100.189 119.048,101.413 121.744,105.845 117.312,103.149 116.088,108.189
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#

# %%
# resize to save
plot!(titlefont=font(14),guidefont=font(14),tickfont=font(12),legendfont=font(12))
#plot!(leg=:best)
plot!(size=(700,850))
savefig("test5b2.png")

# %%
p1=plot(0);
for q in 1:tests
    scatter!(t_solve[:,q],abs_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,label= string(labels[q]))
end
ylabel!("% error")
xlabel!("solve time (s)")
ylims!(0, 10)
#xlims!(0, .1)

p2=plot(0);
for q in 1:tests
    scatter!(t_solve[:,q],abs_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,label= string(labels[q]))
end
ylabel!("% error")
xlabel!("solve time (s)")
ylims!(0, 1)
#xlims!(0, .1)

p3=plot(0);
for q in 1:tests
    scatter!(t_solve[:,q],abs_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,label= string(labels[q]))
end
ylabel!("% error")
xlabel!("solve time (s)")
ylims!(0, .1)
#xlims!(0, .1)

plot(p1,p2,p3,layout=(3,1),background_color_subplot=RGB(0.2,0.2,0.2), background_color_legend=RGB(1,1,1))
plot!(foreground_color_grid=RGB(1,1,1))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 54.7703,103.007 596.063,103.007 596.063,3.93701 54.7703,3.93701
#   " fill="#313131" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="54" y="3" width="542" height="100"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   255.189,101.521 255.189,5.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   474.166,101.521 474.166,5.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,103.007 587.944,103.007
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,83.1934 587.944,83.1934
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,63.3793 587.944,63.3793
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,43.5652 587.944,43.5652
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,23.7511 587.944,23.7511
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,3.93701 587.944,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,103.007 596.063,103.007
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   255.189,103.007 255.189,101.521
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   474.166,103.007 474.166,101.521
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,103.007 54.7703,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,103.007 62.8897,103.007
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,83.1934 62.8897,83.1934
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,63.3793 62.8897,63.3793
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,43.5652 62.8897,43.5652
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,23.7511 62.8897,23.7511
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,3.93701 62.8897,3.93701
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 255.189, 115.007)" x="255.189" y="115.007">0.01</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 474.166, 115.007)" x="474.166" y="115.007">0.02</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 107.507)" x="53.5703" y="107.507">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 87.6934)" x="53.5703" y="87.6934">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 67.8793)" x="53.5703" y="67.8793">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 48.0652)" x="53.5703" y="48.0652">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 28.2511)" x="53.5703" y="28.2511">8</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 8.43701)" x="53.5703" y="8.43701">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 325.417, 130.933)" x="325.417" y="130.933">solve time (s)</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 53.4722)" x="14.4" y="53.4722">% error</text>
# </g>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.9" points="
#   93.2129,110.454 91.9889,105.414 87.5569,108.11 90.2529,103.678 85.2129,102.454 90.2529,101.23 87.5569,96.7977 91.9889,99.4937 93.2129,94.4537 94.4369,99.4937
#   98.8689,96.7977 96.1729,101.23 101.213,102.454 96.1729,103.678 98.8689,108.11 94.4369,105.414 93.2129,110.454
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#0099ff; fill-opacity:0.9" points="
#   93.2129,109.654 92.1113,105.118 88.1225,107.544 90.5489,103.555 86.0129,102.454 90.5489,101.352 88.1225,97.3633 92.1113,99.7897 93.2129,95.2537 94.3145,99.7897
#   98.3033,97.3633 95.8769,101.352 100.413,102.454 95.8769,103.555 98.3033,107.544 94.3145,105.118 93.2129,109.654
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.9" points="
#   96.5647,105.542 95.3407,100.502 90.9087,103.198 93.6047,98.7664 88.5647,97.5424 93.6047,96.3184 90.9087,91.8864 95.3407,94.5824 96.5647,89.5424 97.7887,94.5824
#   102.221,91.8864 99.5247,96.3184 104.565,97.5424 99.5247,98.7664 102.221,103.198 97.7887,100.502 96.5647,105.542
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#0099ff; fill-opacity:0.9" points="
#   96.5647,104.742 95.4631,100.206 91.4743,102.633 93.9007,98.644 89.3647,97.5424 93.9007,96.4408 91.4743,92.452 95.4631,94.8784 96.5647,90.3424 97.6663,94.8784
#   101.655,92.452 99.2287,96.4408 103.765,97.5424 99.2287,98.644 101.655,102.633 97.6663,100.206 96.5647,104.742
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.9" points="
#   93.6254,100.31 92.4014,95.2699 87.9694,97.9659 90.6654,93.5339 85.6254,92.3099 90.6654,91.0859 87.9694,86.6539 92.4014,89.3499 93.6254,84.3099 94.8494,89.3499
#   99.2814,86.6539 96.5854,91.0859 101.625,92.3099 96.5854,93.5339 99.2814,97.9659 94.8494,95.2699 93.6254,100.31
#   "/>
# <polygon clip-path="url(#clip02)" style="fil

# %%
# resize to save
plot!(titlefont=font(14),guidefont=font(14),tickfont=font(12),legendfont=font(12))
#plot!(leg=:best)
plot!(size=(700,850))
savefig("test5c2.png")
