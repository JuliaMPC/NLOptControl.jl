# %%
using NLOptControl
using JuMP
using Ipopt
using Parameters
using Plots
gr()

steps = 20; tests = 5;
global t_solve = Array(Float64, steps, tests) 
global abs_error = Array(Float64, steps, tests) 
global status = Array(Symbol, steps, tests) 
global N = [i+1 for i in 1:steps]
global labels = Array(Symbol,tests)
##################################
# Define NLOptControl problem
##################################
function BrysonDenham{T<:Any}(n::NLOpt,x::Array{T,2},u::Array{T,2}) # dynamic constraint equations
  if n.integrationMethod==:tm
    L = size(x)[1];
  else
    L = size(x)[1]-1;
  end
  dx = Array(Any,L,n.numStates)
  dx[:,1] =  @NLexpression(mdl, [j=1:L], x[j,2] );
  dx[:,2] =  @NLexpression(mdl, [j=1:L], u[j,1] );
  return dx
end
L=1/9;
for q in 1:tests
    for j in 1:steps
        for m in 1:2
            if m==1
                global n = NLOpt();
                n = define(n,stateEquations=BrysonDenham,numStates=2,numControls=1,X0=[0.,1],XF=[0.,-1.],XL=[0.,-Inf],XU=[L,Inf],CL=[-Inf],CU=[Inf])
                if q==1
                    n = configure(n::NLOpt,Ni=1,Nck=[N[j]];(:integrationMethod => :ps),(:integrationScheme => :lgrExplicit),(:finalTimeDV => false),(:tf => 1.0))
                elseif q==2
                    n = configure(n::NLOpt,N=N[j];(:integrationMethod => :tm),(:integrationScheme => :bkwEuler),(:finalTimeDV => false),(:tf => 1.0))
                elseif q==3
                    n = configure(n::NLOpt,N=N[j];(:integrationMethod => :tm),(:integrationScheme => :trapezoidal),(:finalTimeDV => false),(:tf => 1.0))
                elseif q==4 
                    n = configure(n::NLOpt,Ni=2,Nck=[N[j],N[j]];(:integrationMethod => :ps),(:integrationScheme => :lgrExplicit),(:finalTimeDV => false),(:tf => 1.0))
                else
                    n = configure(n::NLOpt,Ni=4,Nck=[N[j],N[j],N[j],N[j]];(:integrationMethod => :ps),(:integrationScheme => :lgrExplicit),(:finalTimeDV => false),(:tf => 1.0))
                end
                ##################################
                # Define JuMP problem
                ##################################
                global mdl = Model(solver = IpoptSolver(print_level=1));
                n,x,u,c=OCPdef(mdl,n)
                global obj = integrate(mdl,n,u[:,1];C=0.5,(:variable=>:control),(:integrand=>:squared))
                @NLobjective(mdl, Min, obj)
                solve(mdl)
            else
                t1 = time();
                status[j,q] = solve(mdl);
                t2 = time();
                t_solve[j,q] = t2 - t1;
                abs_error[j,q]=abs(getvalue(obj) - 4/(9*L))/(4/(9*L))*100;
            end
        end
    end
    if n.integrationMethod==:tm
        labels[q] = string(n.integrationScheme); 
    else
        labels[q] = string(n.integrationScheme, " with Ni = ",n.Ni); 
    end
end
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded
# WARNING: saving objective value and design variable data even though result is either Infeasible or Unbounded
# WARNING: Not solved to optimality, status: Infeasible
# WARNING: saving constraint data even though result is either Infeasible or Unbounded

# %%
p1=plot(0);
for q in 1:tests
    scatter!(t_solve[:,q],abs_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,label= string(labels[q]))
end
ylabel!("% error")
xlabel!("solve time (s)")
#ylims!(0, .1)
xlims!(0, .1)

p2=plot(0);
for q in 1:tests
    scatter!(t_solve[:,q],N,marker = (:star8, 10-q, 0.9),leg=:bottomright,label = string(labels[q]))
end
ylabel!("N")
xlabel!("solve time (s)")
xlims!(0, .1)

plot(p1,p2,layout=(2,1),background_color_subplot=RGB(0.2,0.2,0.2), background_color_legend=RGB(1,1,1))
plot!(foreground_color_grid=RGB(1,1,1))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 45.8815,169.674 596.063,169.674 596.063,3.93701 45.8815,3.93701
#   " fill="#313131" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="45" y="3" width="551" height="166"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   45.8815,167.188 45.8815,6.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   155.918,167.188 155.918,6.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   265.954,167.188 265.954,6.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   375.99,167.188 375.99,6.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   486.027,167.188 486.027,6.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   596.063,167.188 596.063,6.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,164.984 587.81,164.984
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,120.311 587.81,120.311
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,75.6374 587.81,75.6374
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.1342,30.9642 587.81,30.9642
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,169.674 596.063,169.674
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,169.674 45.8815,167.188
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   155.918,169.674 155.918,167.188
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   265.954,169.674 265.954,167.188
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   375.99,169.674 375.99,167.188
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   486.027,169.674 486.027,167.188
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,169.674 596.063,167.188
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,169.674 45.8815,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,164.984 54.1342,164.984
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,120.311 54.1342,120.311
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,75.6374 54.1342,75.6374
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   45.8815,30.9642 54.1342,30.9642
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 45.8815, 181.674)" x="45.8815" y="181.674">0.00</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 155.918, 181.674)" x="155.918" y="181.674">0.02</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 265.954, 181.674)" x="265.954" y="181.674">0.04</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 375.99, 181.674)" x="375.99" y="181.674">0.06</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 486.027, 181.674)" x="486.027" y="181.674">0.08</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 596.063, 181.674)" x="596.063" y="181.674">0.10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 169.484)" x="44.6815" y="169.484">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 124.811)" x="44.6815" y="124.811">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 80.1374)" x="44.6815" y="80.1374">200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 44.6815, 35.4642)" x="44.6815" y="35.4642">300</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 320.972, 197.6)" x="320.972" y="197.6">solve time (s)</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(-90, 14.4, 86.8056)" x="14.4" y="86.8056">% error</text>
# </g>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.9" points="
#   63.784,136.628 62.56,131.588 58.128,134.284 60.824,129.852 55.784,128.628 60.824,127.404 58.128,122.972 62.56,125.668 63.784,120.628 65.008,125.668
#   69.44,122.972 66.744,127.404 71.784,128.628 66.744,129.852 69.44,134.284 65.008,131.588 63.784,136.628
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#0099ff; fill-opacity:0.9" points="
#   63.784,135.828 62.6824,131.292 58.6936,133.718 61.12,129.729 56.584,128.628 61.12,127.526 58.6936,123.537 62.6824,125.964 63.784,121.428 64.8856,125.964
#   68.8744,123.537 66.448,127.526 70.984,128.628 66.448,129.729 68.8744,133.718 64.8856,131.292 63.784,135.828
#   "/>
# <po

# %%
# resize to save
plot!(titlefont=font(14),guidefont=font(14),tickfont=font(12),legendfont=font(12))
#plot!(leg=:best)
plot!(size=(700,850))
savefig("test5a2.png")

# %%
p1=plot(0)
for q in 1:tests
    scatter!(N,abs_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,label = string(labels[q]))
end
xlabel!("N")
ylabel!("% error")

p2=plot(0)
for q in 1:tests
    scatter!(N,abs_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,label = string(labels[q]))
end
xlabel!("N")
ylabel!("% error")
ylims!(0, 30)

p3=plot(0)
for q in 1:tests
    scatter!(N,abs_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#00002d; fill-opacity:0.9" points="
#   116.088,108.189 114.864,103.149 110.432,105.845 113.128,101.413 108.088,100.189 113.128,98.9648 110.432,94.5328 114.864,97.2288 116.088,92.1888 117.312,97.2288
#   121.744,94.5328 119.048,98.9648 124.088,100.189 119.048,101.413 121.744,105.845 117.312,103.149 116.088,108.189
#   "/>
# <polygon clip-path="url(#clip02)" style="fill:#

# %%
# resize to save
plot!(titlefont=font(14),guidefont=font(14),tickfont=font(12),legendfont=font(12))
#plot!(leg=:best)
plot!(size=(700,850))
savefig("test5b2.png")

# %%
p1=plot(0);
for q in 1:tests
    scatter!(t_solve[:,q],abs_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,label= string(labels[q]))
end
ylabel!("% error")
xlabel!("solve time (s)")
ylims!(0, 10)
xlims!(0, .1)

p2=plot(0);
for q in 1:tests
    scatter!(t_solve[:,q],abs_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,label= string(labels[q]))
end
ylabel!("% error")
xlabel!("solve time (s)")
ylims!(0, 1)
xlims!(0, .1)

p3=plot(0);
for q in 1:tests
    scatter!(t_solve[:,q],abs_error[:,q],marker = (:star8, 10-q, 0.9),leg=:bottomright,label= string(labels[q]))
end
ylabel!("% error")
xlabel!("solve time (s)")
ylims!(0, .1)
xlims!(0, .1)

plot(p1,p2,p3,layout=(3,1),background_color_subplot=RGB(0.2,0.2,0.2), background_color_legend=RGB(1,1,1))
plot!(foreground_color_grid=RGB(1,1,1))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 54.7703,103.007 596.063,103.007 596.063,3.93701 54.7703,3.93701
#   " fill="#313131" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="54" y="3" width="542" height="100"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   54.7703,101.521 54.7703,5.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   163.029,101.521 163.029,5.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   271.287,101.521 271.287,5.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   379.546,101.521 379.546,5.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   487.804,101.521 487.804,5.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   596.063,101.521 596.063,5.42306
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,103.007 587.944,103.007
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,83.1934 587.944,83.1934
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,63.3793 587.944,63.3793
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,43.5652 587.944,43.5652
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,23.7511 587.944,23.7511
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#ffffff; stroke-width:0.8; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   62.8897,3.93701 587.944,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,103.007 596.063,103.007
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,103.007 54.7703,101.521
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   163.029,103.007 163.029,101.521
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   271.287,103.007 271.287,101.521
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   379.546,103.007 379.546,101.521
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   487.804,103.007 487.804,101.521
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   596.063,103.007 596.063,101.521
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,103.007 54.7703,3.93701
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,103.007 62.8897,103.007
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,83.1934 62.8897,83.1934
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,63.3793 62.8897,63.3793
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,43.5652 62.8897,43.5652
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,23.7511 62.8897,23.7511
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#00002d; stroke-width:0.8; stroke-opacity:1; fill:none" points="
#   54.7703,3.93701 62.8897,3.93701
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 54.7703, 115.007)" x="54.7703" y="115.007">0.00</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 163.029, 115.007)" x="163.029" y="115.007">0.02</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 271.287, 115.007)" x="271.287" y="115.007">0.04</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 379.546, 115.007)" x="379.546" y="115.007">0.06</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 487.804, 115.007)" x="487.804" y="115.007">0.08</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 596.063, 115.007)" x="596.063" y="115.007">0.10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 107.507)" x="53.5703" y="107.507">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 87.6934)" x="53.5703" y="87.6934">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 67.8793)" x="53.5703" y="67.8793">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 48.0652)" x="53.5703" y="48.0652">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 28.2511)" x="53.5703" y="28.2511">8</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#00002d; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 53.5703, 8.43701)" x="53.5703" y="8.43701">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="f

# %%
# resize to save
plot!(titlefont=font(14),guidefont=font(14),tickfont=font(12),legendfont=font(12))
#plot!(leg=:best)
plot!(size=(700,850))
savefig("test5c2.png")
